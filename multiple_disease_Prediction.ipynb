# %% [markdown]
# # **Importing the Dependencies**
# > Add blockquote

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler    # this is used to standard the data inot same range
from sklearn.model_selection import train_test_split   # this is used to split the data into train and test data
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score  # this is used to check the accuracy of the model

# %% [markdown]
# # **Data collection and Analysis**
#
# PIMA diabetes Dataset - kaggle

# %%
df=pd.read_csv('/content/diabetes (1).csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Replace zero values with NaN in specific columns
cols_with_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
df[cols_with_zero] = df[cols_with_zero].replace(0, np.nan)

# Impute missing values using median by replacing the nan
imputer = SimpleImputer(strategy='median')
df[cols_with_zero] = imputer.fit_transform(df[cols_with_zero])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# number of rows and columns

df.shape
# Out:
# (768, 9)

# %%
# Getting the statical forms of data
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      29.108073  140.671875
# std       3.369578   30.438286      12.096642       8.791221   86.383060
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  121.500000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.455208                  0.471876   33.240885    0.348958
# std      6.875177                  0.331329   11.760232    0.476951
# ...

# %%
df.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 ---> non-diabetes pateint
#
# 1 ---> **`diabetes`** pateint

# %%
df.groupby('Outcome').mean()  # finding the mean by group by
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  110.682000      70.920000      27.726000  127.792000
# 1           4.865672  142.130597      75.123134      31.686567  164.701493
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.885600                  0.429734  31.190000
# 1        35.383582                  0.550500  37.067164

# %% [markdown]
# # **Seperating the Data and Labels**

# %%
x=df.drop(columns = 'Outcome',axis=1)
y=df.Outcome

# %%
#Balancing the Data using SMOTE

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(x, y)

# %%
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # **Data Standradization**

# %%
scaler = StandardScaler()
X_res_scaled = scaler.fit_transform(X_res)

# %%
print(X_res_scaled)  # all have came in the range of same value
# Out:
# [[ 0.63641542  0.70129097 -0.07034849 ...  0.0657504   0.38526686
#    1.41744438]
#  [-0.89049298 -1.32951917 -0.58775299 ... -0.97679533 -0.43695503
#   -0.25875175]
#  [ 1.24717878  1.82951883 -0.76022116 ... -1.46828117  0.51932478
#   -0.1705309 ]
#  ...
#  [ 0.02565206  1.45986993  0.95348474 ...  0.02106987  2.08134633
#    1.50566523]
#  [ 1.24717878 -0.47131293  0.78271262 ...  0.1511047  -0.63575916
#    0.09413165]
#  [ 0.9417971   0.85240182  0.33389761 ... -0.07388449 -0.04299895
#    1.06456098]]

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_res_scaled, y_res, test_size=0.2, stratify=y_res, random_state=42)
print(X_res_scaled.shape)
# Out:
# (1000, 8)

# %% [markdown]
# # **Training the model**

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # **Training the model with logistic** **regression** ***italicised text***

# %%
classifier1=LogisticRegression()
classifier1.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **Training the model with randomforrest classifier italicised text**

# %%
classifier2= RandomForestClassifier(n_estimators=200, random_state=42)
classifier2.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
xgb = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)
xgb.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(64, 32),  # 2 hidden layers with 64 and 32 neurons
    activation='relu',
    solver='adam',
    max_iter=500,
    random_state=42
)

mlp.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)

# %% [markdown]
# # **Model Evluation**
#
# # Accuracy Score **bold text**

# %%
# Accurcy Score in Training data(svm)

x_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(x_train_prediction,Y_train)
print("accuracy of the traning data",training_data_accuracy)
# Out:
# accuracy of the traning data 0.74625

# %%
# Accurcy Score in Test data(svm)

x_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,x_test_prediction)
print("accuracy of the test data",test_data_accuracy)
# Out:
# accuracy of the test data 0.735

# %%
# Accurcy Score in Test data(logistic regression)

x_test_prediction=classifier1.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,x_test_prediction)
print("accuracy of the test data",test_data_accuracy)
# Out:
# accuracy of the test data 0.735

# %%
# Accurcy Score in Training data(logistic regression)

x_train_prediction1=classifier1.predict(X_train)
training_data_accuracy1=accuracy_score(x_train_prediction1,Y_train)
print("accuracy of the traning data",training_data_accuracy1)
# Out:
# accuracy of the traning data 0.7425

# %%
# Accurcy Score in Training data in randomforest

x_train_prediction2=classifier2.predict(X_train)
training_data_accuracy2=accuracy_score(x_train_prediction2,Y_train)
print("accuracy of the traning data",training_data_accuracy2)
# Out:
# accuracy of the traning data 1.0

# %%
# Accurcy Score in Test data in randomforest

x_test_prediction=classifier2.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,x_test_prediction)
print("accuracy of the test data",test_data_accuracy)
# Out:
# accuracy of the test data 0.81

# %%
# Accurcy Score in Test data in mlp

x_test_prediction=mlp.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,x_test_prediction)
print("accuracy of the test data",test_data_accuracy)
# Out:
# accuracy of the test data 0.83

# %%
# Accurcy Score in Test data in xgb

x_test_prediction=xgb.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,x_test_prediction)
print("accuracy of the test data",test_data_accuracy)
# Out:
# accuracy of the test data 0.83

# %% [markdown]
# # **Making a predictive System**

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

#changing the input data int numpy array
input_data_as_numpy_array=np.asarray(input_data)

#reshaping the data
input_reshape_data=input_data_as_numpy_array.reshape(1,-1)

# Strandize the input data
std_data=scaler.transform(input_reshape_data)
print(std_data)

# predicting the value
prediction=classifier.predict(std_data)  # classifier as traning model
print(prediction)


if(prediction[0]==0):
    print("\nThe person is non-diabetic\n")

else:
    print("\nThe person is diabetic\n")
# Out:
# [[ 0.33103374  1.28152244 -0.07034849 -1.26219854  0.33803518 -1.09594341
#    0.26610427  1.50566523]]
# [1]
#
# The person is diabetic
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Saving the Training Model**

# %%
import pickle

# %%
filename='trained_model.sav'
pickle.dump(classifier2,open(filename,'wb'))

# %% [markdown]
# Loading the Saved file

# %%
#loading the saved model
loaded_file=pickle.load(open('trained_model.sav','rb'))

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

#changing the input data int numpy array
input_data_as_numpy_array=np.asarray(input_data)

#reshaping the data
input_reshape_data=input_data_as_numpy_array.reshape(1,-1)

# Strandize the input data
std_data=scaler.transform(input_reshape_data)
print(std_data)

# predicting the value
prediction=loaded_file.predict(std_data)  # classifier as traning model
print(prediction)


if(prediction[0]==0):
    print("\nThe person is non-diabetic\n")
else:
    print("\nThe person is diabetic\n")
# Out:
# [[ 0.33103374  1.28152244 -0.07034849 -1.26219854  0.33803518 -1.09594341
#    0.26610427  1.50566523]]
# [1]
#
# The person is diabetic
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **HEART DISEASES**

# %% [markdown]
# # **Data Collection**

# %%
df1=pd.read_csv('/content/heart_disease_data.csv')
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# number of rows and columns
df1.shape
df1.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Columns where 0 is invalid — adjust according to your dataset
cols_with_zero = ['chol', 'trestbps', 'thalach']

# Replacinf the 0 with nan
df1[cols_with_zero] = df1[cols_with_zero].replace(0, np.nan)

# Impute nan values with median
imputer = SimpleImputer(strategy='median')
df1[cols_with_zero] = imputer.fit_transform(df1[cols_with_zero])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    float64
#  4   chol      302 non-null    float64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    float64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(4), int64(10)
# memory usage: 33.2 KB

# %%
#statistical data of this data frame
df1.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.360927    0.685430    0.970199  131.615894  245.725166    0.149007
# std      9.096686    0.465115    1.032257   17.566716   51.059544    0.356686
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.250000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.529801  149.645695    0.324503    1.036755    1.400662    0.725166
# ...

# %%
# checking for missing values
df1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df1.dropna(how="all")
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0  233.0    1        0    150.0      0      2.3
# 1     37    1   2     130.0  250.0    0        1    187.0      0      3.5
# 2     41    0   1     130.0  204.0    0        0    172.0      0      1.4
# 3     56    1   1     120.0  236.0    0        1    178.0      0      0.8
# 4     57    0   0     120.0  354.0    0        1    163.0      1      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 297   57    0   0     140.0  241.0    0        1    123.0      1      0.2
# 298   45    1   3     110.0  264.0    0        1    132.0      0      1.2
# 299   68    1   0     144.0  193.0    1        1    141.0      0      3.4
# 300   57    1   0     130.0  131.0    0        1    115.0      1      1.2
# 301   57    0   1     130.0  236.0    0        0    174.0      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#counting the the different labels
df1['target'].value_counts()
# Out:
# target
# 1    165
# 0    137
# Name: count, dtype: int64

# %% [markdown]
# 1 --->  heart diseases
#
# 0 --->  no heart diseases

# %% [markdown]
# # **Splitting the features and target**

# %%
data = df1.dropna(subset=['target'])  # replace 'target' with your target column name
X = data.drop('target', axis=1)
y = data['target']

# %%
print(X)
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0  233.0    1        0    150.0      0      2.3
# 1     37    1   2     130.0  250.0    0        1    187.0      0      3.5
# 2     41    0   1     130.0  204.0    0        0    172.0      0      1.4
# 3     56    1   1     120.0  236.0    0        1    178.0      0      0.8
# 4     57    0   0     120.0  354.0    0        1    163.0      1      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 297   57    0   0     140.0  241.0    0        1    123.0      1      0.2
# 298   45    1   3     110.0  264.0    0        1    132.0      0      1.2
# 299   68    1   0     144.0  193.0    1        1    141.0      0      3.4
# 300   57    1   0     130.0  131.0    0        1    115.0      1      1.2
# 301   57    0   1     130.0  236.0    0        0    174.0      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# ...

# %%
print(y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 297    0
# 298    0
# 299    0
# 300    0
# 301    0
# Name: target, Length: 302, dtype: int64

# %%
print(y.isna().sum())
# Out:
# 0

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X,y)

# %% [markdown]
# # **Splitting the data into training data and test data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res,
                                                    test_size=0.2,
                                                    random_state=42)

# %% [markdown]
# # **Model training**

# %%
model=LogisticRegression()

# %%
# Training the logidtic regression

model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # **Model training in svm**

# %%
model1=svm.SVC(kernel='linear')
model1.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # **model training XGB**

# %%
XGB = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)
XGB.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# # **Model training in randomforest**

# %%
model2= RandomForestClassifier(n_estimators=200, random_state=42)
model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %% [markdown]
# # **Model Evaluation and Accuracy Score**

# %%
#Accuracy on training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,y_train)
print("Acurracy on training data : ", training_data_accuracy)
# Out:
# Acurracy on training data :  0.8522727272727273

# %%
#Accuracy on test data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)
print("Acurracy on test data : ", test_data_accuracy)
# Out:
# Acurracy on test data :  0.7272727272727273

# %%
#Accuracy on training data in svm
X_train_prediction=model1.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,y_train)
print("Acurracy on training data : ", training_data_accuracy)
# Out:
# Acurracy on training data :  0.8560606060606061

# %%
#Accuracy on test data in svm
X_test_prediction=model1.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)
print("Acurracy on test data : ", test_data_accuracy)
# Out:
# Acurracy on test data :  0.7272727272727273

# %%
#Accuracy on training data random forest
X_train_prediction=model2.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,y_train)
print("Acurracy on training data : ", training_data_accuracy)
# Out:
# Acurracy on training data :  1.0

# %%
#Accuracy on test data random forest
X_test_prediction=model2.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)
print("Acurracy on test data : ", test_data_accuracy)
# Out:
# Acurracy on test data :  0.8636363636363636

# %%
#Accuracy on test data XGB
X_test_prediction=XGB.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)
print("Acurracy on test data : ", test_data_accuracy)
# Out:
# Acurracy on test data :  0.7727272727272727

# %% [markdown]
# # **Building the Prediction model**

# %%
#input the data
input_data=(56,0,0,134,409,0,0,150,1,1.9,1,2,3)

#changing input data to a numpy array
input_data_as_numpy_array=np.asarray(input_data)

#Reshape the numpy array as we are prediction from one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

#predicting
prediction=model2.predict(input_data_reshaped)
print(prediction)

#condition
if (prediction[0]==0):
  print("\nThe person does not have a heart disease\n")
else:
  print("\nThe person has heart disease\n")
# Out:
# [0]
#
# The person does not have a heart disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Saving the training model**

# %%
import pickle

# %%
filename='heart_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
#loading the saved model
loaded_file=pickle.load(open('heart_model.sav','rb'))

# %%
#input the data
input_data=(56,0,0,134,409,0,0,150,1,1.9,1,2,3)

#changing input data to a numpy array
input_data_as_numpy_array=np.asarray(input_data)

#Reshape the numpy array as we are prediction from one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

#predicting
prediction=model2.predict(input_data_reshaped)
print(prediction)

#condition
if (prediction[0]==0):
  print("\nThe person does not have a heart disease\n")
else:
  print("\nThe person has heart disease\n")
# Out:
# [0]
#
# The person does not have a heart disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **PAKINSON'S DISESES**

# %% [markdown]
# # **making the dataframe**

# %%
df=pd.read_csv("/content/parkinsons (1).data")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.shape #counting the rows and columns
# Out:
# (195, 24)

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# # ***checking the mising values in each column***

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# # **finding the different values in status column lables**

# %%
df.status.value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# 1  ---> Parkinson's positive
#
# 0  ---> parkinson's negative

# %% [markdown]
# # **Grouping the value of status and finding the mean**

# %%
df.groupby('status').mean(numeric_only=True)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %% [markdown]
# # **Data - Pre - processing**
#
# # **separating the status column**

# %%
X=df.drop(columns=['status','name'],axis=1)
Y=df.status
print(X)
print(Y)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %% [markdown]
# # **Splitting the data into training and test data**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# # **Data Standardization**

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 0.63239631 -0.02731081 -0.87985049 ... -0.97586547 -0.55160318
#    0.07769494]
#  [-1.05512719 -0.83337041 -0.9284778  ...  0.3981808  -0.61014073
#    0.39291782]
#  [ 0.02996187 -0.29531068 -1.12211107 ... -0.43937044 -0.62849605
#   -0.50948408]
#  ...
#  [-0.9096785  -0.6637302  -0.160638   ...  1.22001022 -0.47404629
#   -0.2159482 ]
#  [-0.35977689  0.19731822 -0.79063679 ... -0.17896029 -0.47272835
#    0.28181221]
#  [ 1.01957066  0.19922317 -0.61914972 ... -0.716232    1.23632066
#   -0.05829386]]

# %% [markdown]
# # **Support Vector Machine model**

# %%
model= svm.SVC(kernel='linear') #SVC = support vector classifier

# %%
#training the svm model

model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # **TRAINING THE MODEL BY LOGISTIC REGRESSION**

# %%
model1=LogisticRegression()
model1.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **TRAINING THE MODEL BY random forest**

# %%
model2= RandomForestClassifier(n_estimators=200, random_state=42)
model2.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %% [markdown]
# # **RAINING THE MODEL BY XGB**

# %%
XGB=XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)
XGB.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# # **Model evaluation**

# %% [markdown]
# # **checking the accuracy score**

# %%
#accuracy of the training data svm
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(Y_train,X_train_prediction)

# %%
print("accuracy of the traing data: ",training_data_accuracy)
# Out:
# accuracy of the traing data:  0.8846153846153846

# %%
#accuracy of the test data in svm
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,X_test_prediction)
print("accuracy of the test data: ",test_data_accuracy)
# Out:
# accuracy of the test data:  0.8717948717948718

# %%
#accuracy of the training data in logistic regression
X_train_prediction=model1.predict(X_train)
training_data_accuracy=accuracy_score(Y_train,X_train_prediction)
print("accuracy of the traing data: ",training_data_accuracy)
# Out:
# accuracy of the traing data:  0.8717948717948718

# %%
#accuracy of the test data logistic regreesion
X_test_prediction=model1.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,X_test_prediction)
print("accuracy of the test data: ",test_data_accuracy)
# Out:
# accuracy of the test data:  0.8205128205128205

# %%
#accuracy of the training data in randomforest
X_train_prediction=model2.predict(X_train)
training_data_accuracy=accuracy_score(Y_train,X_train_prediction)
print("accuracy of the traing data: ",training_data_accuracy)
# Out:
# accuracy of the traing data:  1.0

# %%
#accuracy of the test data in random forrest
X_test_prediction=model2.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,X_test_prediction)
print("accuracy of the test data: ",test_data_accuracy)
# Out:
# accuracy of the test data:  0.7948717948717948

# %%
#accuracy of the test data in XGB
X_test_prediction=XGB.predict(X_test)
test_data_accuracy=accuracy_score(Y_test,X_test_prediction)
print("accuracy of the test data: ",test_data_accuracy)
# Out:
# accuracy of the test data:  0.8717948717948718

# %% [markdown]
# # **#Building a predictive system**

# %%
input_data=(120.55200,131.16200,113.78700,0.00968,0.00008,0.00463,0.00750,0.01388,0.04701,0.45600,0.02328,0.03526,0.03243,0.06985,0.01222,21.37800,0.415564,0.825069,-4.242867,0.299111,2.187560,0.357775)

#convert to numpy array
input_data_to_num_array=np.asarray(input_data)


#input data reshaped
input_data_reshaped=input_data_to_num_array.reshape(1,-1)

#Standradized the data
std_data=scaler.transform(input_data_reshaped)

#prediction
prediction=model.predict(std_data)
print(prediction)

if(prediction[0]==0):
  print("\nthe person does not have parkinson disease\n")
else:
  print("\nthe person has parkinson disease\n")
# Out:
# [1]
#
# the person has parkinson disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Saving the training model**

# %%
import pickle

# %%
filename='parkinsons_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
#loading the saved model
loaded_file=pickle.load(open('parkinsons_model.sav','rb'))

# %%
input_data=(120.55200,131.16200,113.78700,0.00968,0.00008,0.00463,0.00750,0.01388,0.04701,0.45600,0.02328,0.03526,0.03243,0.06985,0.01222,21.37800,0.415564,0.825069,-4.242867,0.299111,2.187560,0.357775)

#convert to numpy array
input_data_to_num_array=np.asarray(input_data)


#input data reshaped
input_data_reshaped=input_data_to_num_array.reshape(1,-1)

#Standradized the data
std_data=scaler.transform(input_data_reshaped)

#prediction
prediction=model.predict(std_data)
print(prediction)

if(prediction[0]==0):
  print("\nthe person does not have parkinson disease\n")
else:
  print("\nthe person has parkinson disease\n")
# Out:
# [1]
#
# the person has parkinson disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
